# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv
from urllib.parse import urljoin

# %%
def scrape_detik(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        # Ambil konten halaman
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Cari elemen yang mengandung judul berita
        title = soup.find('h1', {'class': 'detail__title'})
        if title:
            title = title.get_text(strip=True)
        else:
            title = "Judul tidak ditemukan"
        
        # Cari elemen yang mengandung isi berita
        content_div = soup.find('div', {'class': 'detail__body-text'})
        if content_div:
            paragraphs = content_div.find_all('p')
            content = '\n'.join([p.get_text(strip=True) for p in paragraphs])
        else:
            content = "Konten tidak ditemukan"
        
        return {
            'title': title,
            'content': content,
            'url': url
        }
        
    except Exception as e:
        print(f"Error saat scraping {url}: {str(e)}")
        return None

# %%
def main():
    # URL target (bisa diganti dengan URL berita spesifik)
    base_url = "https://news.detik.com/berita"
    
    # Daftar URL berita yang akan di-scrape (contoh mengambil beberapa berita terbaru)
    news_urls = []
    
    # Ambil daftar berita dari halaman utama
    try:
        response = requests.get(base_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('article')
        
        for article in articles:
            link = article.find('a')['href']
            full_url = urljoin(base_url, link)
            news_urls.append(full_url)
    except Exception as e:
        print(f"Error mendapatkan daftar berita: {str(e)}")
    
    # Scrape setiap berita
    news_data = []
    for url in news_urls:
        print(f"Memproses: {url}")
        data = scrape_detik(url)
        if data:
            news_data.append(data)
    
    # Simpan ke CSV
    if news_data:
        df = pd.DataFrame(news_data)
        df.to_csv('detik_berita.csv', index=False, quoting=csv.QUOTE_ALL, encoding='utf-8-sig')
        print("Data berhasil disimpan")
    else:
        print("Tidak ada data yang berhasil di-scrape")

if __name__ == "__main__":
    main()
# Out:
# Memproses: https://news.detik.com/berita/d-8025436/anggota-dpr-dengar-kabar-amplop-kondangan-bakal-kena-pajak-oleh-pemerintah
# Memproses: https://news.detik.com/berita/d-8025609/legislator-tegaskan-rkuhap-tak-kerdilkan-kpk-ott-tetap-bisa-lanjut
# Memproses: https://news.detik.com/berita/d-8025571/prabowo-resmi-luncurkan-logo-dan-tema-hut-ke-80-ri
# Memproses: https://news.detik.com/internasional/d-8025575/as-keluar-dari-unesco-china-bukan-tindakan-negara-bertanggung-jawab
# Memproses: https://news.detik.com/berita/d-8025500/lhkpn-terbaru-prabowo-dirilis-jumlah-harta-rp-2-triliun
# Memproses: https://news.detik.com/berita/d-8026072/tawuran-di-matraman-jaktim-tewaskan-1-orang-jatanras-pmj-buru-pelaku
# Memproses: https://news.detik.com/berita/d-8026042/terungkap-pabrik-oli-palsu-di-tangerang-hingga-8-pelaku-ditangkap
# Memproses: https://news.detik.com/berita/d-8025910/tawuran-kelompok-remaja-di-bekasi-lukai-1-warga-4-pelajar-ditangkap
# Memproses: https://news.detik.com/berita/d-8026066/canda-prabowo-minta-ada-studi-serakahnomics-di-kampus-kampus
# Memproses: https://news.detik.com/berita/d-8026063/9-jam-diperiksa-kpk-eks-dirut-bjb-ngaku-dicecar-20-pertanyaan
# Memproses: https://news.detik.com/berita/d-8026060/waka-mpr-siap-ikut-sukseskan-kopdes-merah-putih
# Memproses: https://news.detik.com/berita/d-8026058/siap-siap-balap-sepeda-tour-de-banyuwangi-ijen-bakal-digelar-akhir-juli
# Memproses: https://news.detik.com/berita/d-8026042/terungkap-pabrik-oli-palsu-di-tangerang-hingga-8-pelaku-ditangkap
# Memproses: https://news.detik.com/berita/d-8026038/puan-sebut-tema-hut-ke-80-ri-bukan-sekadar-kata-tapi-arah-perjuangan
# Memproses: https://news.detik.com/berita/d-8026035/kelakar-prabowo-di-hut-pkb-kopi-senjata-rahasia-saya-bisa-bikin-pintar
# Memproses: https://news.detik.com/berita/d-8026033/nasdem-usul-gibran-berkantor-di-ikn-bahlil-golkar-ikut-keputusan-pemerintah
# Memproses: https://news.detik.com/berita/d-8026031/di-depan-prabowo-maruf-minta-tambang-dipakai-untuk-kemakmuran-rakyat
# Memproses: https://news.detik.com/berita/d-8026026/prabowo-terkesan-sambutan-maruf-di-hut-pkb-singkat-tapi-kena-inti-masalah
# Memproses: https://news.detik.com/berita/d-8026024/di-hut-ke-27-pkb-maruf-amin-dukung-prabowo-laksanakan-pasal-33-uud-1945
# Memproses: https://news.detik.com/berita/d-8026002/cak-imin-ungkit-putusan-pemisahan-pemilu-yang-disetujui-pemilihan-dprd-ditunda
# Memproses: https://news.detik.com/berita/d-8025998/prabowo-saya-nyaman-di-tengah-pkb-dan-nu
# Memproses: https://news.detik.com/berita/d-8025974/kementrans-serahkan-sertifikat-shm-ke-transmigran-di-kabupaten-sukabumi
# Memproses: https://news.detik.com/berita/d-8025966/cerita-haru-para-peraih-adhi-makayasa
# Memproses: https://news.detik.com/berita/d-8025955/canda-maruf-sebut-semangat-pkb-seperti-gerindra-gerakan-kiai-indonesia-raya
# Memproses: https://news.detik.com/berita/d-8025954/upacara-hut-ke-80-ri-digelar-di-jakarta-bahlil-di-ikn-masih-sangat-terbatas
# Memproses: https://news.detik.com/berita/d-8025950/la-vela-destinasi-terbaru-di-jakarta-bernuansa-eropa-klasik
# Memproses: https://news.detik.com/berita/d-8025934/kejagung-periksa-bos-sugar-group-companies-terkait-kasus-tppu-zarof-ricar
# Memproses: https://news.detik.com/berita/d-8025930/mendagri-dorong-lulusan-ipdn-jadi-agen-perubahan-di-asn
# Memproses: https://news.detik.com/berita/d-8025928/pejabat-pemprov-diperiksa-kpk-kasus-proyek-jalan-gubsu-bobby-jamin-kooperatif
# Memproses: https://news.detik.com/berita/d-8025914/prabowo-dan-gibran-hadiri-harlah-ke-27-pkb-di-jcc
# Memproses: https://news.detik.com/berita/d-8025913/legislator-minta-anggaran-bpom-tak-dipotong-sebut-merek-ecek-ecek-bertebaran
# Memproses: https://news.detik.com/berita/d-8025910/tawuran-kelompok-remaja-di-bekasi-lukai-1-warga-4-pelajar-ditangkap
# Memproses: https://news.detik.com/berita/d-8025903/polisi-selidiki-kasus-kecelakaan-maut-motor-vs-mobil-di-jaksel
# Memproses: https://news.detik.com/berita/d-8025901/andra-soni-ajak-walkot-tangerang-dan-tangsel-susur-kali-angke-ini-temuannya
# Memproses: https://news.detik.com/berita/d-8025895/bri-peduli-ajak-siswa-sd-di-garut-pelajari-pertanian
# Memproses: https://news.detik.com/berita/d-8025892/lestari-moerdijat-dorong-kedepankan-prinsip-kemanusiaan-dalam-kasus-tpks
# Memproses: https://news.detik.com/berita/d-8025891/buron-kasus-pembunuhan-maling-motor-di-jakbar-untuk-beli-sabu
# Memproses: https://news.detik.com/berita/d-8025888/cerita-bram-patria-yoshugi-terpilih-jadi-pemenang-sayembara-logo-hut-ke-80-ri
# Memproses: https://news.detik.com/berita/d-8025875/wacana-ikn-jadi-kantor-bumn-erick-thohir-bilang-begini
# Memproses: https://news.detik.com/berita/d-8025873/kpk-lacak-aliran-duit-di-kasus-pemerasan-izin-tenaga-kerja-asing-kemnaker
# Memproses: https://news.detik.com/berita/d-8025859/pco-buka-suara-soal-transfer-data-pribadi-ri-ke-as
# Memproses: https://news.detik.com/berita/d-8025817/maling-motor-di-jakbar-ditangkap-ternyata-buron-kasus-pembunuhan
# Memproses: https://news.detik.com/berita/d-8025813/legislator-minta-kemenhub-pecat-petugas-ksop-lalai-usai-insiden-kmp-tunu-jaya
# Memproses: https://news.detik.com/berita/d-8025801/periksa-eks-dirut-bjb-kpk-dalami-payung-hukum-dana-di-luar-anggaran-resmi
# Memproses: https://news.detik.com/berita/d-8025789/pedoman-visual-hut-ke-80-ri-isi-dan-link-unduh-pdf
# Memproses: https://news.detik.com/berita/d-8025747/menkomdigi-meutya-buka-suara-soal-kesepakatan-transfer-data-pribadi-ri-as
# Memproses: https://news.detik.com/berita/d-8025744/jokowi-ungkap-ijazah-asli-sma-dan-s1-miliknya-disita-penyidik
# Memproses: https://news.detik.com/berita/d-8025735/kpk-sita-usd-3-5-juta-di-kasus-korupsi-diduga-rugikan-negara-rp-80-m
# Memproses: https://news.detik.com/berita/d-8025731/tito-optimistis-lulusan-ipdn-mampu-perkuat-sistem-administrasi-pemerintah
# Memproses: https://news.detik.com/berita/d-8025719/bang-jago-palak-penjual-kopi-di-cengkareng-ngaku-ormas-minta-uang-keamanan
# Memproses: https://news.detik.com/berita/d-8025716/gerindra-soal-peluang-pdip-masuk-pemerintahan-usai-prabowo-sebut-adik-kakak
# Memproses: https://news.detik.com/berita/d-8025703/polisi-bongkar-peran-8-tersangka-kasus-pabrik-oli-palsu-di-tangerang
# Memproses: https://news.detik.com/berita/d-8025699/cerita-mega-ke-pramono-sekarang-beda-ada-pasukan-oranye-dulu-kok-jarang
# Memproses: https://news.detik.com/berita/d-8025694/kakorlantas-ajak-komunitas-otomotif-jateng-tertib-lalu-lintas-demi-indonesia-emas
# Memproses: https://news.detik.com/berita/d-8025650/belasan-juta-batang-rokok-ilegal-yang-bikin-negara-rugi-rp-12-m-dimusnahkan
# Memproses: https://news.detik.com/berita/d-8025640/pramono-minta-jajaran-hati-hati-saya-bisa-minta-ppatk-cek-transaksi
# Memproses: https://news.detik.com/berita/d-8025630/wapres-gibran-punya-harta-rp-27-5-m-di-lhkpn-terbaru-ini-daftarnya
# Memproses: https://news.detik.com/berita/d-8025627/resmi-ini-tema-dan-link-download-logo-hut-ke-80-ri
# Memproses: https://www.detik.com/tag/prabowo
# Memproses: https://www.detik.com/tag/kopdes-merah-putih
# Memproses: https://www.detik.com/tag/diplomat-kemlu-tewas
# Memproses: https://news.detik.com/berita/d-8025888/cerita-bram-patria-yoshugi-terpilih-jadi-pemenang-sayembara-logo-hut-ke-80-ri
# Memproses: https://news.detik.com/berita/d-8025934/kejagung-periksa-bos-sugar-group-companies-terkait-kasus-tppu-zarof-ricar
# Memproses: https://news.detik.com/berita/d-8025747/menkomdigi-meutya-buka-suara-soal-kesepakatan-transfer-data-pribadi-ri-as
# Memproses: https://news.detik.com/berita/d-8025966/cerita-haru-para-peraih-adhi-makayasa
# Memproses: https://news.detik.com/berita/d-8026042/terungkap-pabrik-oli-palsu-di-tangerang-hingga-8-pelaku-ditangkap
# Memproses: https://news.detik.com/berita/d-8018094/tom-lembong-divonis-4-5-tahun-penjara
# Memproses: https://news.detik.com/berita/d-8023138/alasan-kesehatan-jokowi-minta-pemeriksaan-soal-tudingan-ijazah-palsu-ditunda
# Memproses: https://news.detik.com/berita/d-8016753/dpr-setujui-tambahan-anggaran-halal-2026-rp-2-1-t-untuk-3-5-juta-sertifikat-halal-gratis-dan-bangun-upt-di-seluruh-indonesia
# Data berhasil disimpan

# %%
def main():
    # URL target (bisa diganti dengan URL berita spesifik)
    base_url = "https://news.detik.com/jabodetabek"
    
    # Daftar URL berita yang akan di-scrape (contoh mengambil beberapa berita terbaru)
    news_urls = []
    
    # Ambil daftar berita dari halaman utama
    try:
        response = requests.get(base_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('article')
        
        for article in articles:
            link = article.find('a')['href']
            full_url = urljoin(base_url, link)
            news_urls.append(full_url)
    except Exception as e:
        print(f"Error mendapatkan daftar berita: {str(e)}")
    
    # Scrape setiap berita
    news_data = []
    for url in news_urls:
        print(f"Memproses: {url}")
        data = scrape_detik(url)
        if data:
            news_data.append(data)
    
    # Simpan ke CSV
    if news_data:
        df = pd.DataFrame(news_data)
        df.to_csv('detik_jabodetabek.csv', index=False, quoting=csv.QUOTE_ALL, encoding='utf-8-sig')
        print("Data berhasil disimpan")
    else:
        print("Tidak ada data yang berhasil di-scrape")

if __name__ == "__main__":
    main()
# Out:
# Memproses: https://news.detik.com/berita/d-8026091/cegah-banjir-sekitar-kali-angke-pemda-kaji-bongkar-bendung-polor-di-tangerang
# Memproses: https://news.detik.com/berita/d-8026072/tawuran-di-matraman-jaktim-tewaskan-1-orang-jatanras-pmj-buru-pelaku
# Memproses: https://news.detik.com/berita/d-8026042/terungkap-pabrik-oli-palsu-di-tangerang-hingga-8-pelaku-ditangkap
# Memproses: https://news.detik.com/berita/d-8026072/tawuran-di-matraman-jaktim-tewaskan-1-orang-jatanras-pmj-buru-pelaku
# Memproses: https://news.detik.com/berita/d-8026042/terungkap-pabrik-oli-palsu-di-tangerang-hingga-8-pelaku-ditangkap
# Memproses: https://news.detik.com/berita/d-8025910/tawuran-kelompok-remaja-di-bekasi-lukai-1-warga-4-pelajar-ditangkap
# Memproses: https://news.detik.com/berita/d-8025903/polisi-selidiki-kasus-kecelakaan-maut-motor-vs-mobil-di-jaksel
# Memproses: https://news.detik.com/berita/d-8025891/buron-kasus-pembunuhan-maling-motor-di-jakbar-untuk-beli-sabu
# Memproses: https://news.detik.com/berita/d-8025817/maling-motor-di-jakbar-ditangkap-ternyata-buron-kasus-pembunuhan
# Memproses: https://news.detik.com/berita/d-8025719/bang-jago-palak-penjual-kopi-di-cengkareng-ngaku-ormas-minta-uang-keamanan
# Memproses: https://news.detik.com/berita/d-8025703/polisi-bongkar-peran-8-tersangka-kasus-pabrik-oli-palsu-di-tangerang
# Memproses: https://news.detik.com/berita/d-8025640/pramono-minta-jajaran-hati-hati-saya-bisa-minta-ppatk-cek-transaksi
# Memproses: https://news.detik.com/berita/d-8025499/boks-lampu-lalin-di-cawang-dimodifikasi-usai-disabotase-pak-ogah
# Memproses: https://news.detik.com/berita/d-8025488/team-ogah-mundur-vs-cibinong-all-base-tawuran-di-bogor-3-remaja-ditangkap
# Memproses: https://news.detik.com/berita/d-8025424/ditanya-penyidik-soal-sosok-ir-kasmudjo-jokowi-dosen-pembimbing-saya
# Memproses: https://news.detik.com/berita/d-8025410/pembunuh-wanita-terborgol-di-cisauk-sempat-sewa-psk-selama-di-pelarian
# Memproses: https://news.detik.com/berita/d-8025325/pria-di-koja-tendang-kakek-stroke-hingga-tewas-gara-gara-aroma-pesing
# Memproses: https://news.detik.com/berita/d-8025315/janjian-tawuran-lewat-medsos-9-remaja-di-jaksel-ditangkap
# Memproses: https://news.detik.com/berita/d-8025309/pemkot-bogor-seleksi-400-pengamen-untuk-menyanyi-di-kafe-hingga-alun-alun
# Memproses: https://news.detik.com/berita/d-8025251/wawalkot-bogor-ajak-pengamen-yang-maki-sopir-angkot-jadi-petugas-kebersihan
# Memproses: https://news.detik.com/berita/d-8025217/bhabin-polres-bogor-mediasi-kasus-video-settingan-di-stadion-pakansari-jaga-kondusivitas
# Memproses: https://news.detik.com/berita/d-8025185/hari-anak-nasional-pramono-undang-anak-kurang-mampu-ke-balai-kota
# Memproses: https://news.detik.com/berita/d-8025160/pramono-soal-pembongkaran-tiang-monorel-tunggu-arahan-penegak-hukum
# Memproses: https://news.detik.com/berita/d-8025141/pramono-soal-dugaan-beras-oplosan-food-station-tak-boleh-ditutup-tutupi
# Memproses: https://news.detik.com/berita/d-8025130/dana-operasional-rt-rw-di-jakarta-naik-25-mulai-oktober
# Memproses: https://news.detik.com/berita/d-8025058/pabrik-makanan-di-tajurhalang-bogor-kebakaran-diduga-akibat-korsleting
# Memproses: https://news.detik.com/berita/d-8025057/kebakaran-rumah-di-matraman-dalam-jakpus-70-personel-damkar-dikerahkan
# Memproses: https://news.detik.com/berita/d-8025036/pramono-akan-gelar-rapat-dengan-walkot-bahas-lahan-mangkrak-jadi-rth-lusa
# Memproses: https://news.detik.com/berita/d-8025022/polisi-ungkap-pemicu-pengamen-mabuk-maki-maki-sopir-angkot-di-bogor
# Memproses: https://news.detik.com/berita/d-8025012/3-penjual-oli-palsu-di-jakbar-ditangkap-puluhan-botol-disita
# Memproses: https://news.detik.com/berita/d-8024981/viral-konvoi-pemotor-bakar-flare-petasan-di-jalan-taman-mini-jaktim
# Memproses: https://news.detik.com/berita/d-8024973/penampakan-2-kunci-pintu-kos-lokasi-diplomat-kemlu-tewas-misterius
# Memproses: https://news.detik.com/berita/d-8024943/kronologi-beni-residivis-narkoba-bunuh-kakak-di-jaktim-berawal-transaksi-sabu
# Memproses: https://news.detik.com/berita/d-8024941/pramono-akan-bangun-4-pltsa-dulu-sampah-beban-kini-seperti-harta-karun
# Memproses: https://news.detik.com/berita/d-8024898/satpol-pp-bongkar-79-bangunan-hingga-pkl-liar-di-jl-juanda-depok
# Memproses: https://news.detik.com/berita/d-8024856/dishub-curigai-pak-ogah-di-balik-matinya-lampu-lalin-di-cawang
# Memproses: https://news.detik.com/berita/d-8024826/kesan-pramono-pertama-kali-naik-transj-pakai-jas-rasa-mau-ke-kawinan
# Memproses: https://news.detik.com/berita/d-8024774/viral-maling-curi-uang-kotak-amal-di-musala-depok-polisi-cek-tkp
# Memproses: https://news.detik.com/berita/d-8024773/ada-bisnis-sabu-di-balik-kasus-adik-bunuh-kakak-di-jaktim
# Memproses: https://news.detik.com/berita/d-8024734/tampang-beni-residivis-narkoba-pembunuh-kakak-di-jaktim
# Memproses: https://news.detik.com/berita/d-8024723/viral-pengamen-mabuk-maki-maki-sopir-angkot-di-bogor-pelaku-ditangkap
# Memproses: https://news.detik.com/berita/d-8024689/jatuh-dari-motor-terlindas-truk-2-orang-tewas-di-jakut
# Memproses: https://news.detik.com/berita/d-8024670/tj-rute-blok-m-ancol-dan-70-bus-listrik-high-deck-bakal-diluncurkan-bulan-ini
# Data berhasil disimpan

# %%
def main():
    # URL target (bisa diganti dengan URL berita spesifik)
    base_url = "https://news.detik.com/internasional"
    
    # Daftar URL berita yang akan di-scrape (contoh mengambil beberapa berita terbaru)
    news_urls = []
    
    # Ambil daftar berita dari halaman utama
    try:
        response = requests.get(base_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('article')
        
        for article in articles:
            link = article.find('a')['href']
            full_url = urljoin(base_url, link)
            news_urls.append(full_url)
    except Exception as e:
        print(f"Error mendapatkan daftar berita: {str(e)}")
    
    # Scrape setiap berita
    news_data = []
    for url in news_urls:
        print(f"Memproses: {url}")
        data = scrape_detik(url)
        if data:
            news_data.append(data)
    
    # Simpan ke CSV
    if news_data:
        df = pd.DataFrame(news_data)
        df.to_csv('detik_internasional.csv', index=False, quoting=csv.QUOTE_ALL, encoding='utf-8-sig')
        print("Data berhasil disimpan")
    else:
        print("Tidak ada data yang berhasil di-scrape")

if __name__ == "__main__":
    main()
# Out:
# Memproses: https://news.detik.com/berita/d-8025436/anggota-dpr-dengar-kabar-amplop-kondangan-bakal-kena-pajak-oleh-pemerintah
# Memproses: https://news.detik.com/berita/d-8025609/legislator-tegaskan-rkuhap-tak-kerdilkan-kpk-ott-tetap-bisa-lanjut
# Memproses: https://news.detik.com/berita/d-8025571/prabowo-resmi-luncurkan-logo-dan-tema-hut-ke-80-ri
# Memproses: https://news.detik.com/internasional/d-8025575/as-keluar-dari-unesco-china-bukan-tindakan-negara-bertanggung-jawab
# Memproses: https://news.detik.com/berita/d-8025500/lhkpn-terbaru-prabowo-dirilis-jumlah-harta-rp-2-triliun
# Memproses: https://news.detik.com/dw/d-8025824/dampak-serangan-situs-nuklir-iran-apakah-segawat-chernobyl
# Memproses: https://news.detik.com/dw/d-8025300/peran-pemimpin-druze-al-hijri-di-balik-pertumpahan-darah-di-suriah
# Memproses: https://news.detik.com/dw/d-8025121/trump-umumkan-tarif-impor-jepang-jadi-15
# Memproses: https://news.detik.com/internasional/d-8025908/tuduhan-serius-trump-ke-obama-soal-pimpin-upaya-kudeta
# Memproses: https://news.detik.com/internasional/d-8025821/5-berita-terpopuler-internasional-hari-ini
# Memproses: https://news.detik.com/internasional/d-8025709/drone-junta-myanmar-jatuh-di-perbatasannya-thailand-protes
# Memproses: https://news.detik.com/internasional/d-8025632/pm-malaysia-umumkan-blt-untuk-redakan-amarah-warga-demo-tetap-lanjut
# Memproses: https://news.detik.com/internasional/d-8025575/as-keluar-dari-unesco-china-bukan-tindakan-negara-bertanggung-jawab
# Memproses: https://news.detik.com/internasional/d-8025519/jet-tempur-supersonik-mirage-jatuh-kehilangan-pertama-bagi-ukraina
# Memproses: https://news.detik.com/internasional/d-8025469/111-organisasi-kemanusiaan-sorot-kelaparan-massal-menyebar-di-gaza
# Memproses: https://news.detik.com/internasional/d-8025388/bukan-cuma-pengkhianatan-trump-tuduh-obama-pimpin-upaya-kudeta
# Memproses: https://news.detik.com/internasional/d-8025343/rusia-gelar-latihan-angkatan-laut-besar-besaran-di-samudra-pasifik
# Memproses: https://news.detik.com/dw/d-8025300/peran-pemimpin-druze-al-hijri-di-balik-pertumpahan-darah-di-suriah
# Memproses: https://news.detik.com/internasional/d-8025249/bom-nuklir-as-diam-diam-dibawa-ke-inggris-ada-apa
# Memproses: https://news.detik.com/internasional/d-8025145/horor-2-pesawat-nyaris-tabrakan-di-meksiko-jaraknya-cuma-60-meter
# Memproses: https://news.detik.com/dw/d-8025121/trump-umumkan-tarif-impor-jepang-jadi-15
# Memproses: https://news.detik.com/internasional/d-8025075/malaysia-turunkan-harga-bbm-dan-bagi-bagi-duit-ke-warga-18-tahun-ke-atas
# Memproses: https://news.detik.com/internasional/d-8025016/ada-soal-transfer-data-pribadi-dalam-kesepakatan-dagang-as-ri
# Memproses: https://news.detik.com/internasional/d-8024899/israel-sambut-baik-as-keluar-dari-unesco-ini-langkah-yang-diperlukan
# Memproses: https://news.detik.com/internasional/d-8024817/trump-tiba-tiba-tuduh-obama-lakukan-pengkhianatan-ada-apa
# Memproses: https://news.detik.com/abc-australia/d-8024806/dunia-hari-ini-penyanyi-legendaris-ozzy-osbourne-meninggal-dunia
# Memproses: https://news.detik.com/bbc-world/d-8024778/kelaparan-warga-gaza-rela-mati-demi-sekantong-tepung-terigu
# Memproses: https://news.detik.com/internasional/d-8024777/pm-jepang-akan-umumkan-pengunduran-diri-usai-kalah-pemilu
# Memproses: https://news.detik.com/dw/d-8024742/kenapa-trump-gunakan-tarif-ketimbang-sanksi-ekonomi
# Memproses: https://news.detik.com/dw/d-8024649/china-bikin-bendungan-plta-terbesar-dunia-india-dan-bangladesh-ketar-ketir
# Memproses: https://news.detik.com/internasional/d-8024523/data-miris-diungkap-pbb-israel-duduki-hampir-90-persen-wilayah-gaza
# Memproses: https://news.detik.com/internasional/d-8024485/tambang-batu-bara-di-afghanistan-runtuh-6-penambang-tewas
# Memproses: https://news.detik.com/internasional/d-8024479/ukraina-bekuk-7-agen-rusia-diduga-rencanakan-teror-5-di-antaranya-remaja
# Memproses: https://news.detik.com/internasional/d-8024471/21-anak-di-gaza-tewas-karena-malnutrisi-kelaparan-dalam-3-hari-terakhir
# Memproses: https://news.detik.com/internasional/d-8024456/tanah-longsor-di-pakistan-tewaskan-5-orang-15-masih-hilang
# Memproses: https://news.detik.com/internasional/d-8024426/pbb-israel-bunuh-1-054-warga-gaza-saat-antre-bantuan-pangan-sejak-mei
# Memproses: https://news.detik.com/internasional/d-8024347/28-negara-desak-israel-setop-perang-di-gaza-jepang-hingga-inggris
# Memproses: https://news.detik.com/internasional/d-8024235/oma-oma-gangsta-yang-ternyata-bos-kartel-narkoba
# Memproses: https://news.detik.com/internasional/d-8024029/pilu-dokter-pekerja-kemanusiaan-gaza-pingsan-saat-tugas-karena-lapar
# Memproses: https://news.detik.com/internasional/d-8023990/5-berita-terpopuler-internasional-hari-ini
# Memproses: https://news.detik.com/internasional/d-8023981/banjir-terjang-manila-puluhan-ribu-orang-mengungsi-2-hilang
# Memproses: https://news.detik.com/dw/d-8023930/jerman-undang-diplomat-taliban-buka-layanan-konsuler
# Memproses: https://news.detik.com/internasional/d-8023881/korut-akan-bikin-kapal-perang-terbaru-berbobot-5-000-ton
# Memproses: https://news.detik.com/internasional/d-8023790/israel-kembali-serang-gaza-15-orang-tewas
# Memproses: https://news.detik.com/dw/d-8023725/ukraina-rekrut-tentara-dengan-kondisi-sakit-mental-kok
# Memproses: https://news.detik.com/internasional/d-8023637/trump-tak-suka-warga-gaza-dibunuh-saat-antre-bantuan
# Memproses: https://news.detik.com/dw/d-8023555/dukungan-ke-partai-sayap-kanan-meningkat-babak-baru-politik-jepang
# Memproses: https://news.detik.com/abc-australia/d-8023517/dunia-hari-ini-australia-inggris-dan-prancis-menuntut-diakhirinya-perang-gaza
# Memproses: https://news.detik.com/internasional/d-8023490/pbb-sorot-87-persen-wilayah-gaza-di-bawah-perintah-militer-israel
# Memproses: https://news.detik.com/bbc-world/d-8023398/kisah-gangsta-debbs-kartel-narkoba-rp-1-7-t-dipimpin-nenek-nenek
# Memproses: https://news.detik.com/internasional/d-8023378/trump-rilis-240-000-halaman-dokumen-pembunuhan-martin-luther-king
# Memproses: https://news.detik.com/internasional/d-8023280/israel-cegat-rudal-dari-yaman-usai-gempur-pelabuhan-yang-dikuasai-houthi
# Memproses: https://news.detik.com/internasional/d-8023213/trump-terkejut-dengan-serangan-israel-ke-suriah-dan-gereja-katolik-gaza
# Memproses: https://news.detik.com/internasional/d-8023156/iran-akui-pengeboman-as-bikin-pengayaan-uranium-terhenti
# Memproses: https://news.detik.com/dw/d-8023127/inilah-para-perempuan-jagoan-pembangkang-hitler
# Memproses: https://news.detik.com/bbc-world/d-8023080/ribuan-warga-afghanistan-diusir-iran-karena-dituduh-jadi-mata-mata-israel
# Memproses: https://news.detik.com/internasional/d-8023073/pilu-25-orang-tewas-saat-pesawat-latih-bangladesh-jatuh-menimpa-sekolah
# Memproses: https://news.detik.com/internasional/d-8022925/korban-tewas-pesawat-jatuh-di-bangladesh-jadi-20-orang-termasuk-pilot
# Memproses: https://www.detik.com/tag/prabowo
# Memproses: https://www.detik.com/tag/kopdes-merah-putih
# Memproses: https://www.detik.com/tag/diplomat-kemlu-tewas
# Memproses: https://news.detik.com/berita/d-8025888/cerita-bram-patria-yoshugi-terpilih-jadi-pemenang-sayembara-logo-hut-ke-80-ri
# Memproses: https://news.detik.com/berita/d-8025934/kejagung-periksa-bos-sugar-group-companies-terkait-kasus-tppu-zarof-ricar
# Memproses: https://news.detik.com/berita/d-8026042/terungkap-pabrik-oli-palsu-di-tangerang-hingga-8-pelaku-ditangkap
# Memproses: https://news.detik.com/berita/d-8025747/menkomdigi-meutya-buka-suara-soal-kesepakatan-transfer-data-pribadi-ri-as
# Memproses: https://news.detik.com/berita/d-8025966/cerita-haru-para-peraih-adhi-makayasa
# Memproses: https://news.detik.com/berita/d-8018094/tom-lembong-divonis-4-5-tahun-penjara
# Memproses: https://news.detik.com/berita/d-8023138/alasan-kesehatan-jokowi-minta-pemeriksaan-soal-tudingan-ijazah-palsu-ditunda
# Memproses: https://news.detik.com/berita/d-8016753/dpr-setujui-tambahan-anggaran-halal-2026-rp-2-1-t-untuk-3-5-juta-sertifikat-halal-gratis-dan-bangun-upt-di-seluruh-indonesia
# Data berhasil disimpan

# %%
def main():
    # URL target (bisa diganti dengan URL berita spesifik)
    base_url = "https://news.detik.com/hukum"
    
    # Daftar URL berita yang akan di-scrape (contoh mengambil beberapa berita terbaru)
    news_urls = []
    
    # Ambil daftar berita dari halaman utama
    try:
        response = requests.get(base_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('article')
        
        for article in articles:
            link = article.find('a')['href']
            full_url = urljoin(base_url, link)
            news_urls.append(full_url)
    except Exception as e:
        print(f"Error mendapatkan daftar berita: {str(e)}")
    
    # Scrape setiap berita
    news_data = []
    for url in news_urls:
        print(f"Memproses: {url}")
        data = scrape_detik(url)
        if data:
            news_data.append(data)
    
    # Simpan ke CSV
    if news_data:
        df = pd.DataFrame(news_data)
        df.to_csv('detik_hukum.csv', index=False, quoting=csv.QUOTE_ALL, encoding='utf-8-sig')
        print("Data berhasil disimpan")
    else:
        print("Tidak ada data yang berhasil di-scrape")

if __name__ == "__main__":
    main()
# Out:
# Memproses: https://news.detik.com/berita/d-8025436/anggota-dpr-dengar-kabar-amplop-kondangan-bakal-kena-pajak-oleh-pemerintah
# Memproses: https://news.detik.com/berita/d-8025609/legislator-tegaskan-rkuhap-tak-kerdilkan-kpk-ott-tetap-bisa-lanjut
# Memproses: https://news.detik.com/berita/d-8025571/prabowo-resmi-luncurkan-logo-dan-tema-hut-ke-80-ri
# Memproses: https://news.detik.com/internasional/d-8025575/as-keluar-dari-unesco-china-bukan-tindakan-negara-bertanggung-jawab
# Memproses: https://news.detik.com/berita/d-8025500/lhkpn-terbaru-prabowo-dirilis-jumlah-harta-rp-2-triliun
# Memproses: https://news.detik.com/berita/d-8025604/viral-bang-jago-bawa-sangkur-palak-penjual-kopi-gerobak-di-cengkareng
# Memproses: https://news.detik.com/berita/d-8025325/pria-di-koja-tendang-kakek-stroke-hingga-tewas-gara-gara-aroma-pesing
# Memproses: https://news.detik.com/berita/d-8024943/kronologi-beni-residivis-narkoba-bunuh-kakak-di-jaktim-berawal-transaksi-sabu
# Memproses: https://news.detik.com/berita/d-8025325/pria-di-koja-tendang-kakek-stroke-hingga-tewas-gara-gara-aroma-pesing
# Memproses: https://news.detik.com/berita/d-8024877/kpk-periksa-eks-dirut-bjb-tersangka-kasus-korupsi-pengadaan-iklan
# Memproses: https://news.detik.com/berita/d-8024201/bank-jakarta-dukung-penuh-proses-hukum-kasus-kredit-pt-sritex
# Memproses: https://news.detik.com/berita/d-8023955/jaksa-minta-hotman-baca-lengkap-dokumen-terkait-impor-gula-jangan-dipotong
# Memproses: https://news.detik.com/berita/d-8023859/bem-fh-unnes-kritik-rkuhap-komisi-iii-jauh-lebih-baik-dari-kuhap-lama
# Memproses: https://news.detik.com/berita/d-8023460/lawan-vonis-4-5-tahun-penjara-tom-lembong-resmi-ajukan-banding
# Memproses: https://news.detik.com/berita/d-8022848/tom-lembong-banding-jaksa-tak-bergeming
# Memproses: https://news.detik.com/berita/d-8022256/ma-kurangi-uang-pengganti-emirsyah-satar-dari-rp-1-4-t-jadi-rp-817-m
# Memproses: https://news.detik.com/berita/d-8022105/pria-bunuh-kakak-di-kebon-nanas-jatinegara-jaktim-ditangkap
# Memproses: https://news.detik.com/berita/d-8022041/eks-dirjen-prasetyo-divonis-7-5-tahun-bui-di-kasus-korupsi-rel-ka-sumut-aceh
# Memproses: https://news.detik.com/berita/d-8021057/vonis-bui-dan-denda-tom-lembong-meski-disebut-tak-nikmati-duit-korupsi
# Memproses: https://news.detik.com/berita/d-8020893/viral-pria-luka-di-kepala-gegara-tawuran-di-jonggol-bogor-polisi-lacak-pelaku
# Memproses: https://news.detik.com/berita/d-8020746/curi-7-ponsel-pria-ditangkap-usai-kepergok-congkel-jendela-rumah-di-bogor
# Memproses: https://news.detik.com/berita/d-8020426/tom-lembong-dihukum-denda-rp-750-juta-meski-disebut-tak-nikmati-hasil-korupsi
# Memproses: https://news.detik.com/berita/d-8020002/alasan-hakim-tetap-hukum-tom-lembong-meski-tak-nikmati-hasil-korupsi
# Memproses: https://news.detik.com/berita/d-8019938/kerugian-negara-di-kasus-tom-lembong-dakwaan-rp-578-m-putusan-rp-194-m
# Memproses: https://news.detik.com/berita/d-8018321/eks-direktur-pt-ppi-divonis-4-tahun-penjara-di-kasus-korupsi-impor-gula
# Memproses: https://news.detik.com/berita/d-8018307/tom-lembong-soal-divonis-4-5-tahun-penjara-hakim-bilang-tak-ada-niat-jahat
# Memproses: https://news.detik.com/berita/d-8018290/hakim-kerugian-negara-di-kasus-korupsi-gula-tom-lembong-rp-194-miliar
# Memproses: https://news.detik.com/berita/d-8018264/hakim-abaikan-keterangan-eks-menteri-bumn-saat-jatuhkan-vonis-ke-tom-lembong
# Memproses: https://news.detik.com/berita/d-8018242/hakim-nyatakan-tom-lembong-tak-nikmati-hasil-korupsi-kasus-gula
# Memproses: https://news.detik.com/berita/d-8018210/hakim-perintahkan-jaksa-balikin-ipad-dan-macbook-tom-lembong
# Memproses: https://news.detik.com/berita/d-8018187/tom-lembong-langsung-peluk-istri-usai-divonis-4-5-tahun-penjara
# Memproses: https://news.detik.com/berita/d-8018171/hal-memberatkan-vonis-tom-lembong-terkesan-kedepankan-ekonomi-kapitalis
# Memproses: https://news.detik.com/berita/d-8018149/tom-lembong-divonis-4-5-tahun-penjara-pengunjung-sidang-riuh
# Memproses: https://news.detik.com/berita/d-8018094/tom-lembong-divonis-4-5-tahun-penjara
# Memproses: https://news.detik.com/berita/d-8017964/hakim-nilai-tom-lembong-paham-izin-impor-ke-8-perusahaan-gula-langgar-aturan
# Memproses: https://news.detik.com/berita/d-8017830/sidang-vonis-hasto-kristiyanto-digelar-jumat-25-juli
# Memproses: https://news.detik.com/berita/d-8017650/benarkah-mk-larang-wakil-menteri-rangkap-jadi-komisaris
# Memproses: https://news.detik.com/berita/d-8017526/ekspresi-tom-lembong-jelang-pembacaan-sidang-vonis-kasus-gula
# Memproses: https://news.detik.com/berita/d-8017497/nasib-sejoli-di-cakung-ditangkap-polisi-usai-buang-bayi-depan-rumah-pak-haji
# Memproses: https://news.detik.com/berita/d-8017416/mk-bilang-tak-segampang-itu-ubah-rp-1-000-jadi-rp-1
# Memproses: https://news.detik.com/berita/d-8017303/di-ruang-sidang-hasto-bawa-bawa-kasus-anas-urbaningrum-dan-antasari-azhar
# Memproses: https://news.detik.com/berita/d-8017234/sarang-burung-saksi-bisu-sopir-ekspedisi-tewas-dikeroyok-dan-diikat-di-tiang
# Memproses: https://news.detik.com/berita/d-8016682/kpk-tetapkan-4-tersangka-gratifikasi-pengadaan-katalis-bensin
# Memproses: https://news.detik.com/berita/d-8016334/tolak-ubah-rp-1-000-jadi-rp-1-mk-harus-dilakukan-pembentuk-uu
# Memproses: https://news.detik.com/berita/d-8016306/ditolak-gugatan-redenominasi-rp-1-000-jadi-rp-1-kandas-di-mk
# Memproses: https://news.detik.com/berita/d-8016266/ulah-tak-tahu-diri-anak-punk-tangsel-dibantu-malah-gorok-begal-korban
# Memproses: https://news.detik.com/berita/d-8016251/alasan-mk-tolak-gugatan-agar-capres-cawapres-minimal-s-1
# Memproses: https://news.detik.com/berita/d-8016052/pemohon-meninggal-gugatan-agar-menteri-wamen-tak-jadi-komisaris-gugur-di-mk
# Memproses: https://news.detik.com/berita/d-8015603/mahasiswa-bunuh-mahasiswa-di-aceh-lolos-dari-vonis-mati
# Memproses: https://news.detik.com/berita/d-8015545/2-pelaku-tawuran-dan-penjarahan-di-cempaka-putih-dibekuk-lainnya-diburu
# Memproses: https://www.detik.com/tag/prabowo
# Memproses: https://www.detik.com/tag/kopdes-merah-putih
# Memproses: https://www.detik.com/tag/diplomat-kemlu-tewas
# Memproses: https://news.detik.com/berita/d-8025888/cerita-bram-patria-yoshugi-terpilih-jadi-pemenang-sayembara-logo-hut-ke-80-ri
# Memproses: https://news.detik.com/berita/d-8025934/kejagung-periksa-bos-sugar-group-companies-terkait-kasus-tppu-zarof-ricar
# Memproses: https://news.detik.com/berita/d-8026042/terungkap-pabrik-oli-palsu-di-tangerang-hingga-8-pelaku-ditangkap
# Memproses: https://news.detik.com/berita/d-8025747/menkomdigi-meutya-buka-suara-soal-kesepakatan-transfer-data-pribadi-ri-as
# Memproses: https://news.detik.com/berita/d-8025966/cerita-haru-para-peraih-adhi-makayasa
# Memproses: https://news.detik.com/berita/d-8018094/tom-lembong-divonis-4-5-tahun-penjara
# Memproses: https://news.detik.com/berita/d-8023138/alasan-kesehatan-jokowi-minta-pemeriksaan-soal-tudingan-ijazah-palsu-ditunda
# Memproses: https://news.detik.com/berita/d-8016753/dpr-setujui-tambahan-anggaran-halal-2026-rp-2-1-t-untuk-3-5-juta-sertifikat-halal-gratis-dan-bangun-upt-di-seluruh-indonesia
# Data berhasil disimpan

# %%
# List semua file CSV yang ingin digabungkan
file_paths = [
    'detik_berita.csv', 'detik_jabodetabek.csv', 'detik_internasional.csv', 'detik_hukum.csv'
]

# Membaca dan menggabungkan semua file
all_data = pd.concat((pd.read_csv(file) for file in file_paths), ignore_index=True)

# Menyimpan hasil gabungan ke file baru
all_data.to_csv('detik.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd
import ollama
from tqdm import tqdm

# %%
# Pilih model yang lebih ringan
MODEL_NAME = "phi3"

# Fungsi yang dioptimalkan
def generate_qa_light(text):
    prompt = f"""
    Buat 1 pertanyaan dan jawaban singkat (maks 20 kata) dari teks berikut:
    {text[:1000]}  # Lebih pendek untuk menghemat memori
    Format: Pertanyaan: <pertanyaan>\nJawaban: <jawaban>
    """
    
    try:
        response = ollama.generate(
            model=MODEL_NAME,
            prompt=prompt,
            options={
                "temperature": 0.3,  # Kurangi kreativitas untuk hasil lebih konsisten
                "num_ctx": 1024  # Batasi context window
            }
        )
        return response['response']
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
# Proses CSV dengan optimasi memori
def process_csv(input_path, output_path, sample_size=None):
    df = pd.read_csv(input_path)
    if sample_size:
        df = df.sample(min(sample_size, len(df)))
    
    results = []
    for _, row in tqdm(df.iterrows(), total=len(df)):
        generated = generate_qa_light(str(row['content']))
        if generated:
            try:
                q = generated.split("Pertanyaan: ")[1].split("\n")[0].strip()
                a = generated.split("Jawaban: ")[1].strip() if "Jawaban: " in generated else "-"
                results.append({
                    'content': row.get('content', ''),
                    'question': q,
                    'answer': a
                })
            except:
                continue
    
    pd.DataFrame(results).to_csv(output_path, index=False)

process_csv('detik.csv', 'detik_qa.csv', sample_size=50)
# Out:
# 100%|██████████| 50/50 [41:30<00:00, 49.81s/it]
